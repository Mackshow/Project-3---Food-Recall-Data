# %%
import pandas as pd

# %%
# Save and read data files
nuts = "nuts_df.csv"

nuts_df = pd.read_csv(nuts)

nuts_df
# Out:
#       Unnamed: 0                             name_brand     industry_name  \
# 0              6                 MARIANI SLICED ALMONDS  Nuts/Edible Seed
# 1             12               JIF CREAMY PEANUT BUTTER  Nuts/Edible Seed
# 2             26          ALNAHKA HALWA WITH PISTACHIOS  Nuts/Edible Seed
# 3             31          NATURAL CHOICES PEANUT BUTTER  Nuts/Edible Seed
# 4             36   MARGARET HOLMES GREEN BOILED PEANUTS  Nuts/Edible Seed
# ...          ...                                    ...               ...
# 5423      206081         PETER PAN CREAMY PEANUT BUTTER  Nuts/Edible Seed
# 5424      206083  PLANTERS PEANUTS DRY ROASTED UNSALTED  Nuts/Edible Seed
# 5425      206112    TRADER JOE'S DRY TOASTED PIGNOLIA'S  Nuts/Edible Seed
# 5426      206118                     PINNEOLA PINE NUTS  Nuts/Edible Seed
# 5427      206153      AURORA NATURAL PIGNOLIA PINE NUTS  Nuts/Edible Seed
#
#      report_number consumer_gender date_created  \
# ...

# %%
nuts_df['consumer_gender'].value_counts()
# Out:
# consumer_gender
# Female          2964
# Male            2051
# Not Reported       6
# Unknown            4
# Name: count, dtype: int64

# %%
# Save and read data files
peanuts = "peanut_product_df.csv"

peanut_product = pd.read_csv(peanuts)

peanut_product
# Out:
#       Unnamed: 0                                      name_brand  \
# 0             12                        JIF CREAMY PEANUT BUTTER
# 1             31                   NATURAL CHOICES PEANUT BUTTER
# 2             33  PILLSBURY BIG DELUXE PEANUT BUTTER CUP COOKIES
# 3             36            MARGARET HOLMES GREEN BOILED PEANUTS
# 4             83  SKIPPY REDUCED FAT CREAMY PEANUT BUTTER SPREAD
# ...          ...                                             ...
# 4240      206200           PROTEIN BAR DELUXE - CHOCOLATE PEANUT
# 4241      206260            ADVOBAR MEAL CHOCOLATE PEANUT BUTTER
# 4242      206261            MEAL REPLACEMENT SHAKE PEANUT BUTTER
# 4243      206269     CRACKER JACKS POPCORN AND PEANUT SNACK FOOD
# 4244      206559     LANCE TOASTED CHEESE CRACKERS PEANUT BUTTER
#
#                                      industry_name report_number  \
# 0                                 Nuts/Edible Seed        109955
# ...

# %%
peanut_product['consumer_gender'].value_counts()
# Out:
# consumer_gender
# Female          2195
# Male            1700
# Unknown            5
# Not Reported       5
# Name: count, dtype: int64
